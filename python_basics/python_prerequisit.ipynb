# %% [markdown]
# # Basics of Python

# %%
"""
Program: Hello World
Description: First program to display a greeting message.
Author: Govind Mishra
Created: 12 March 2026
"""

def main():
    """Run the Hello World program."""
    print("Hello, World!")


if __name__ == "__main__":
    main()

# %% [markdown]
# ## Why Python Language is Required?

# %%
def explain_python_for_ai_genai():
    reasons = [
        "Simple and readable syntax: Focus on AI/ML concepts, not language complexity.",
        "Strong ecosystem: NumPy, pandas, scikit-learn, TensorFlow, PyTorch, Hugging Face, and more.",
        "Fast prototyping: Quickly experiment, test models, and iterate in notebooks.",
        "Powerful data handling: Excellent tools for cleaning, transforming, and analyzing data.",
        "Industry standard: Most tutorials, research code, and production AI workflows use Python.",
        "GenAI-ready integrations: Rich SDK support for LLMs, vector DBs, and orchestration frameworks.",
        "Huge community support: Abundant docs, examples, and open-source projects.",
        "End-to-end workflow: Build, train, evaluate, deploy, automate—all in one language.",
    ]

    title = " WHY PYTHON FOR GENAI & AI/ML? "
    line = "═" * 78

    print(f"\n╔{line}╗")
    print(f"║{title.center(78)}║")
    print(f"╚{line}╝\n")

    for i, reason in enumerate(reasons, start=1):
        print(f"✨ {i:02}. {reason}")

    print("\n🚀 Python makes AI learning faster, clearer, and more practical.")

explain_python_for_ai_genai()
# Out:
# ╔══════════════════════════════════════════════════════════════════════════════╗
# ║                        WHY PYTHON FOR GENAI & AI/ML?                         ║
# ╚══════════════════════════════════════════════════════════════════════════════╝
#
# ✨ 01. Simple and readable syntax: Focus on AI/ML concepts, not language complexity.
# ✨ 02. Strong ecosystem: NumPy, pandas, scikit-learn, TensorFlow, PyTorch, Hugging Face, and more.
# ✨ 03. Fast prototyping: Quickly experiment, test models, and iterate in notebooks.
# ✨ 04. Powerful data handling: Excellent tools for cleaning, transforming, and analyzing data.
# ✨ 05. Industry standard: Most tutorials, research code, and production AI workflows use Python.
# ✨ 06. GenAI-ready integrations: Rich SDK support for LLMs, vector DBs, and orchestration frameworks.
# ✨ 07. Huge community support: Abundant docs, examples, and open-source projects.
# ✨ 08. End-to-end workflow: Build, train, evaluate, deploy, automate—all in one language.
#
# ...
