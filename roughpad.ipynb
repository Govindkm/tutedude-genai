# %%
customers = [{"id": 1, "name": "Asha"}, {"id": 2, "name": "Ravi"}]
orders = [{"customer_id": 1, "item": "Book"}, {"customer_id": 2, "item": "Pen"}]

# TODO: write one list comprehension to produce:
# ["Asha bought Book", "Ravi bought Pen"]
result = [
    # your code here
    f"{customer['name']} bought {order['item']}" 
    for customer in customers for order in orders if customer["id"] == order['customer_id']
]

print(result)
# Out:
# ['Asha bought Book', 'Ravi bought Pen']
