# %% [markdown]
# # Assignment 5: Importing, Creating Modules & Packages
#
# ## Problem Statement
# You are working as a Python developer in a small utility tools team. This assignment focuses on organizing code into modules and packages and importing them in clean, scalable ways.
#
# ## This Assignment Focuses On
# - Creating Python modules (`.py` files)
# - Importing modules in different styles
# - Creating packages using `__init__.py`
# - Using `from module import function` and `import module`
# - Keeping the code beginner-friendly and readable
#
# ## Required Folder Structure
# ```text
# module_assignment/
#   main.py
#   math_utils.py
#   string_utils.py
#   shop_package/
#     __init__.py
#     discount.py
#     billing.py
# ```
#
# ## Restrictions
# - Do not use OOP, exceptions, or extra file I/O beyond creating Python files.
# - Keep function logic simple.
# - Focus on understanding modules and packages only.

# %% [markdown]
# ## Task 1: Create a Simple Module (`math_utils.py`)
# Create a module with these functions:
# 1. `add(a, b)` returns `a + b`
# 2. `subtract(a, b)` returns `a - b`
# 3. `square(n)` returns `n * n`
#
# In `main.py`, import this module in two ways:
# - `import math_utils`
# - `from math_utils import square`
#
# Test all functions.

# %%
# Task 1 notes
# TODO: Write add(), subtract(), and square() in math_utils.py
# TODO: Import and test functions from main.py

# Example tests to run from main.py:
# print(math_utils.add(10, 5))
# print(math_utils.subtract(10, 5))
# print(square(7))

# %% [markdown]
# ## Task 2: Create Another Module (`string_utils.py`)
# Create a module with:
# 1. `capitalize_words(text)` returns text with each word capitalized
# 2. `reverse_string(text)` returns reversed text
#
# Import this module in `main.py` and test both functions.

# %%
# Task 2 notes
# TODO: Implement capitalize_words() and reverse_string() in string_utils.py
# TODO: Import string_utils in main.py and run tests

# Example tests:
# print(string_utils.capitalize_words("hello python world"))
# print(string_utils.reverse_string("module"))

# %% [markdown]
# ## Task 3: Create a Simple Package (`shop_package`)
# Inside `shop_package`, create:
#
# ### `discount.py`
# - `apply_discount(price, percent)` returns discounted price
# - `bulk_discount(price)` always subtracts 50 from price
#
# ### `billing.py`
# - `calculate_total(prices)` returns total bill (sum of all prices)
# - `apply_tax(amount)` adds 8% tax
#
# ### `__init__.py`
# Re-export functions with imports such as:
# - `from .discount import apply_discount, bulk_discount`
# - `from .billing import calculate_total, apply_tax`

# %%
# Task 3 notes
# TODO: Implement discount.py, billing.py, and __init__.py

# Suggested quick checks:
# prices = [400, 600, 250, 100]
# print(calculate_total(prices))
# print(apply_tax(1000))
# print(apply_discount(1000, 20))
# print(bulk_discount(300))

# %% [markdown]
# ## Task 4: Import the Package in `main.py`
# In `main.py`, do the following:
# 1. Import the package/module, for example `import shop_package.discount as disc`
# 2. Import selected functions, for example `from shop_package.billing import calculate_total`
# 3. Call every function created in the package
#
# Use sample data:
# ```python
# prices = [400, 600, 250, 100]
# ```

# %%
# Task 4 notes
# TODO: In main.py import the package using both import styles
# TODO: Call all module and package functions

# Suggested output checks:
# print(calculate_total([400, 600, 250, 100]))
# print(disc.apply_discount(1000, 20))
# print(disc.bulk_discount(500))

# %% [markdown]
# ## Submission Guidelines
# - Do not use AI.
# - Create one main folder for submission.
# - Include all code files and README if required.
# - Zip the folder and upload it on the submission portal.
