# %% [markdown]
# # Assignment 3: Python - Functions
#
# ## Problem Statement
# You are a Python developer building small utilities for an online billing system. This assignment practices user-defined functions, recursion, lambda functions, map(), and filter().
#
# ## Topics Included
# - User-defined functions
# - Default arguments
# - Recursive functions
# - Lambda functions
# - map()
# - filter()
# - Combining functions with data processing
#
# ## Restrictions
# - Do not use classes, external packages, exceptions, or file handling.
# - Keep the solutions simple and readable.
# - Complete each task in its own clearly labeled code cell.

# %% [markdown]
# ## Task 1: Basic Function - Apply Discount
# Write a function `apply_discount(price, discount_percent=5)` that:
# 1. Receives a price and a discount percentage.
# 2. Returns the price after applying the discount.
# 3. Uses a default discount of 5% when no percentage is provided.
#
# Test it with:
# - `apply_discount(1000, 10)`
# - `apply_discount(500)`
# - `apply_discount(5000, 60)`

# %%
# Task 1 solution
def apply_discount(price, discount_percent=5):
    # TODO: Calculate and return the discounted price
    pass

# TODO: Test the function with all three examples

# %% [markdown]
# ## Task 2: Recursive Function - Factorial
# Create a recursive function `factorial(n)` that:
# 1. Returns `1` when `n` is `0` or `1`.
# 2. Returns a clear message when `n` is negative.
# 3. Calls itself for positive values greater than `1`.
#
# Test it with:
# - `factorial(5)`
# - `factorial(0)`
# - `factorial(-3)`

# %%
# Task 2 solution
def factorial(n):
    # TODO: Add the base cases and recursive case
    pass

# TODO: Test the function with all three examples

# %% [markdown]
# ## Task 3: Lambda Function - GST Calculator
# Create a lambda function that adds 18% GST to a price.
#
# Use it to calculate the final prices for `100`, `500`, and `1000`.
# Print the results rounded to two decimal places.

# %%
# Task 3 solution
# TODO: Create a lambda function that adds 18% GST
gst_price = None
prices = [100, 500, 1000]

# TODO: Use the lambda function and print each final price

# %% [markdown]
# ## Task 4: Using map() - Apply GST to a List
# Given the list:
# ```python
# prices = [100, 250, 400, 1200, 50]
# ```
#
# Use `map()` and a lambda function to add 18% GST to every price.
# Print both the original prices and the prices after GST.

# %%
# Task 4 solution
prices = [100, 250, 400, 1200, 50]

# TODO: Use map() and lambda to apply 18% GST
gst_prices = []

print(f"Original prices: {prices}")
print(f"Prices after GST: {gst_prices}")

# %% [markdown]
# ## Task 5: Using filter() - Find Expensive Products
# Given the list:
# ```python
# prices = [100, 250, 400, 1200, 50, 700]
# ```
#
# Use `filter()` and a lambda function to keep only prices greater than `500`.
# Print the resulting list of expensive products.

# %%
# Task 5 solution
prices = [100, 250, 400, 1200, 50, 700]

# TODO: Use filter() and lambda to keep prices above 500
expensive_products = []

print(f"Expensive products: {expensive_products}")

# %% [markdown]
# ## Task 6: Combined Utility Function
# Write a function `process_prices(prices, discount_percent=10)` that:
# 1. Receives a list of prices and a discount percentage.
# 2. Uses `map()` and `lambda` to apply the discount to every price.
# 3. Uses `filter()` and `lambda` to keep only discounted prices above `300`.
# 4. Returns the filtered list.
#
# Test it with:
# ```python
# prices = [100, 500, 250, 1000, 50, 450]
# ```

# %%
# Task 6 solution
def process_prices(prices, discount_percent=10):
    # TODO: Use map() and lambda to apply the discount
    # TODO: Use filter() and lambda to keep values above 300
    # TODO: Return the filtered list
    pass

prices = [100, 500, 250, 1000, 50, 450]
# TODO: Call the function and print the result

# %% [markdown]
# ## Task 7: Mini Project - Menu Using Functions
# Create a menu-driven price utility using functions.
#
# Create these functions:
# 1. `add_price(prices, price)` - adds a price to the list.
# 2. `get_average_price(prices)` - returns the average price.
# 3. `get_max_price(prices)` - returns the highest price.
# 4. `show_menu()` - displays the available options.
#
# The menu should support:
# - `1` - Add a price
# - `2` - Show the average price
# - `3` - Show the highest price
# - `q` - Quit
#
# Use a loop and function calls to keep the menu running until the user chooses `q`.

# %%
# Task 7 solution
prices = []

def add_price(prices, price):
    # TODO: Add the price and return the updated list
    pass

def get_average_price(prices):
    # TODO: Return the average price
    pass

def get_max_price(prices):
    # TODO: Return the highest price
    pass

def show_menu():
    # TODO: Print the menu options
    pass

# TODO: Build the menu loop using the functions above
# Use input(), if/elif/else, continue, and break where appropriate.

# %% [markdown]
# ## Submission Guidelines
# - Do not use AI to write the solutions.
# - Keep this notebook inside your main assignment folder.
# - Include a README if your mentor or institute requires one.
# - Run all completed cells before submitting the notebook.
# - Review the outputs and make sure each task is clearly labeled.
